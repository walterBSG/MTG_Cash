# %%
import json
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from itertools import islice
from datetime import datetime as dt
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping

# %%
#data = open('data/AllPrintings.json', 'r', encoding='utf-8')
#data = json.load(data)
#prices = open('data/AllPrices.json', 'r', encoding='utf-8')
#prices = json.load(data/prices)
#prices = prices['data']

# %%
def getCardData(card, prices):
    text = power = toughness = manaCost = isReprint = ''
    if 'text' in card:
        text = card['text']
    if 'power' in card:
        power = card['power']
    if 'toughness' in card:
        toughness = card['toughness']
    if 'manaCost' in card:
        manaCost = card['manaCost'].replace('}{',' ').replace('{','').replace('}','')
    if 'isReprint' in card:
        isReprint = card['isReprint']
    card = {'name' : card['name'],
            'manaCost' : manaCost,
            'type' : card['type'],
            'text' : text,
            'power' : power,
            'toughness' : toughness,
            'setCode' : card['setCode'],
            'rarity' : card['rarity'],
            'legalities' : card['legalities'],
            'isReprint' : isReprint,
            'prices': prices}
    return card

def prepareCards(data, adjustedPrices):
    cards = {}
    for k, sets in data['data'].items():
        for card in sets['cards']:
            if card['uuid'] not in adjustedPrices.keys(): continue
            cards[card['uuid']] = getCardData(card, adjustedPrices[card['uuid']])
    return cards

def adjustPriceData(filteredPrices):
    ajustedPrices = {}
    for uuid, provider in filteredPrices.items():
        if 'cardkingdom' in provider.keys():
            if 'foil' in provider['cardkingdom'].keys():
                ckf = provider['cardkingdom']['foil']
            else:
                ckf = 0
        if 'cardkingdom' in provider.keys():
            if 'normal' in provider['cardkingdom'].keys():
                ckn = provider['cardkingdom']['normal']
            else:
                ckn = 0
        if 'tcgplayer' in provider.keys():
            if 'foil' in provider['tcgplayer'].keys():
                tcgf = provider['tcgplayer']['foil']
            else:
                tcgf = 0
        if 'tcgplayer' in provider.keys():
            if 'normal' in provider['tcgplayer'].keys():
                tcgn = provider['tcgplayer']['normal']
            else:
                tcgn = 0
        ajustedPrices[uuid] = [ckf, ckn, tcgf, tcgn]
    return ajustedPrices

def getPrices(prices):
    filteredPrices = {}
    for uuid, form in prices.items():
        for typeofcard, lists in form.items():
            prov = {}
            for provider, buylist in lists.items():
                types = {}
                if 'buylist' in buylist.keys():
                    for quality, dates in buylist['buylist'].items():
                        date = max(dates.keys(), key=lambda d: dt.strptime(d, '%Y-%m-%d'))
                        types[quality] = dates[date]
                prov[provider] = types
        filteredPrices[uuid] = prov
    filteredPrices = adjustPriceData(filteredPrices)
    return filteredPrices

# %%
#adjustedPrices = getPrices(prices)
#cards = prepareCards(data, adjustedPrices)

# %%
#print(dict(islice(adjustedPrices.items(), 0, 10)))

# %%
#data = pd.DataFrame.from_dict(cards, orient='index').reset_index(drop=True)
#data.to_pickle('data/data.pkl')
data = pd.read_pickle('data/data.pkl')

# %%
y = data['prices'].tolist()

# %%
x = data.drop(columns=['prices'])
x.size
# Out:
# 664670

# %%
len(y)
# Out:
# 66467

# %%
x.head()
# Out:
#                 name manaCost                     type  \
# 0  Ancestor's Chosen    5 W W  Creature — Human Cleric
# 1  Ancestor's Chosen    5 W W  Creature — Human Cleric
# 2     Angel of Mercy      4 W         Creature — Angel
# 3     Angel of Mercy      4 W         Creature — Angel
# 4   Angelic Blessing      2 W                  Sorcery
#
#                                                 text power toughness setCode  \
# 0  First strike (This creature deals combat damag...     4         4     10E
# 1  First strike (This creature deals combat damag...     4         4     10E
# 2  Flying\nWhen Angel of Mercy enters the battlef...     3         3     10E
# 3  Flying\nWhen Angel of Mercy enters the battlef...     3         3     10E
# 4  Target creature gets +3/+3 and gains flying un...                     10E
#
#      rarity                                         legalities isReprint
# 0  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 1  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 2  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'gladi...      True
# 3  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'gladi...      True
# 4    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True

# %%
data.head()
# Out:
#                 name manaCost                     type  \
# 0  Ancestor's Chosen    5 W W  Creature — Human Cleric
# 1  Ancestor's Chosen    5 W W  Creature — Human Cleric
# 2     Angel of Mercy      4 W         Creature — Angel
# 3     Angel of Mercy      4 W         Creature — Angel
# 4   Angelic Blessing      2 W                  Sorcery
#
#                                                 text power toughness setCode  \
# 0  First strike (This creature deals combat damag...     4         4     10E
# 1  First strike (This creature deals combat damag...     4         4     10E
# 2  Flying\nWhen Angel of Mercy enters the battlef...     3         3     10E
# 3  Flying\nWhen Angel of Mercy enters the battlef...     3         3     10E
# 4  Target creature gets +3/+3 and gains flying un...                     10E
#
#      rarity                                         legalities isReprint  \
# 0  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 1  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 2  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'gladi...      True
# 3  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'gladi...      True
# 4    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
#
#                     prices
# 0       [0, 0.26, 0, 0.58]
# 1    [0.08, 0, 0.02, 0.01]
# 2  [1.58, 0.1, 4.45, 0.01]
# 3      [0.6, 0, 0.5, 0.01]
# 4    [0.12, 0.05, 0.35, 0]

# %%
# Process the input data
x['text'] = x[x.columns[1:]].apply(lambda x: ' '.join(x.dropna().astype(str)),axis=1)
x = x['text'].tolist()
x = np.array(x)
y = np.array(y)
VOCAB_SIZE = 15000

# %%
# Define the encoder
encoder = tf.keras.layers.TextVectorization(max_tokens=VOCAB_SIZE)
encoder.adapt(x)

# Define the model
model = tf.keras.Sequential([
    encoder,  # Add the encoder to the model
    tf.keras.layers.Embedding(
        input_dim=VOCAB_SIZE,
        output_dim=128,
        # Use masking to handle the variable sequence lengths
        mask_zero=True),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128, return_sequences=True)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(128)),
    tf.keras.layers.Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.001)),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4)
])
# Compile the model with an optimizer and a loss function
model.compile(optimizer='adam', loss='mean_absolute_error')

# %%
# Split the data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.2)
X_val, X_test, y_val, y_test = train_test_split(x, y, test_size=0.5)

# %%
# Train the model
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
plateau = tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.1, patience=10, verbose=0, mode="auto", min_delta=0.0001, cooldown=0, min_lr=0)
checkpoint = tf.keras.callbacks.ModelCheckpoint(filep
saving model to model\checkpoint.ckpt
# 831/831 [==============================] - 52s 62ms/step - loss: 2.7057 - val_loss: 2.4271 - lr: 0.0010
# Epoch 138/250
# 830/831 [============================>.] - ETA: 0s - loss: 2.7003
# Epoch 138: saving model to model\checkpoint.ckpt
# 831/831 [==============================] - 54s 65ms/step - loss: 2.7009 - val_loss: 2.4787 - lr: 0.0010

# %%
# Evaluate the model on the test set
test_loss= model.evaluate(X_test, y_test, return_dict=True)
print('Test loss:', test_loss)
# Out:
# 1039/1039 [==============================] - 18s 17ms/step - loss: 2.6464
# Test loss: {'loss': 2.646355390548706}

# %%
model.save('model/model', save_format="tf")
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_1_layer_call_fn, lstm_cell_1_layer_call_and_return_conditional_losses, lstm_cell_2_layer_call_fn, lstm_cell_2_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn while saving (showing 5 of 8). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: model/model\assets
# INFO:tensorflow:Assets written to: model/model\assets

# %%
data.head(50)
# Out:
#                         name manaCost                              type  \
# 0          Ancestor's Chosen    5 W W           Creature — Human Cleric
# 1          Ancestor's Chosen    5 W W           Creature — Human Cleric
# 2             Angel of Mercy      4 W                  Creature — Angel
# 3             Angel of Mercy      4 W                  Creature — Angel
# 4           Angelic Blessing      2 W                           Sorcery
# 5           Angelic Blessing      2 W                           Sorcery
# 6             Angelic Chorus    3 W W                       Enchantment
# 7               Angelic Wall      1 W                   Creature — Wall
# 8               Angelic Wall      1 W                   Creature — Wall
# 9            Aura of Silence    1 W W                       Enchantment
# 10          Aven Cloudchaser      3 W           Creature — Bird Soldier
# 11          Aven Cloudchaser      3 W           Creature — Bird Soldier
# 12            Ballista Squad      3 W            Creature — Human Rebel
# 13                   Bandage        W                           Instant
# 14     Beacon of Immortality      5 W                           Instant
# 15           Benalish Knight      2 W           Creature — Human Knight
# 16           Benalish Knight      2 W           Creature — Human Knight
# 17  Cho-Manno, Revolutionary    2 W W  Legendary Creature — Human Rebel
# 18                   Condemn        W                           Instant
# 19                 Demystify        W                           Instant
# 20             Field Marshal    1 W W          Creature — Human Soldier
# 21             Field Marshal    1 W W          Creature — Human Soldier
# 22              Ghost Warden      1 W                 Creature — Spirit
# 23           Glorious Anthem    1 W W                       Enchantment
# 24            Hail of Arrows      X W                           Instant
# 25            Heart of Light      2 W                Enchantment — Aura
# 26            Heart of Light      2 W                Enchantment — Aura
# 27               High Ground        W                       Enchantment
# 28                  Holy Day        W                           Instant
# 29             Holy Strength        W                Enchantment — Aura
# 30             Holy Strength        W                Enchantment — Aura
# 31               Honor Guard        W          Creature — Human Soldier
# 32            Icatian Priest        W           Creature — Human Cleric
# 33     Kjeldoran Royal Guard    3 W W          Creature — Human Soldier
# 34            Loxodon Mystic    3 W W        Creature — Elephant Cleric
# 35              Loyal Sentry        W          Creature — Human Soldier
# 36                 Luminesce        W                           Instant
# 37              Mobilization      2 W                       Enchantment
# 38              Mobilization      2 W                       Enchantment
# 39           Nomad Mythmaker      2 W     Creature — Human Nomad Cleric
# 40           Nomad Mythmaker      2 W     Creature — Human Nomad Cleric
# 41                  Pacifism      1 W                Enchantment — Aura
# 42                  Pacifism      1 W                Enchantment — Aura
# 43            Paladin en-Vec    1 W W           Creature — Human Knight
# 44            Paladin en-Vec    1 W W           Creature — Human Knight
# 45                    Pariah      2 W                Enchantment — Aura
# 46                    Pariah      2 W                Enchantment — Aura
# 47             Reviving Dose      2 W                           Instant
# 48          Reya Dawnbringer  6 W W W        Legendary Creature — Angel
# 49          Reya Dawnbringer  6 W W W        Legendary Creature — Angel
#
#                                                  text power toughness setCode  \
# 0   First strike (This creature deals combat damag...     4         4     10E
# 1   First strike (This creature deals combat damag...     4         4     10E
# 2   Flying\nWhen Angel of Mercy enters the battlef...     3         3     10E
# 3   Flying\nWhen Angel of Mercy enters the battlef...     3         3     10E
# 4   Target creature gets +3/+3 and gains flying un...                     10E
# 5   Target creature gets +3/+3 and gains flying un...                     10E
# 6   Whenever a creature enters the battlefield und...                     10E
# 7      Defender (This creature can't attack.)\nFlying     0         4     10E
# 8      Defender (This creature can't attack.)\nFlying     0         4     10E
# 9   Artifact and enchantment spells your opponents...                     10E
# 10  Flying (This creature can't be blocked except ...     2         2     10E
# 11  Flying (This creature can't be blocked except ...     2         2     10E
# 12  {X}{W}, {T}: Ballista Squad deals X damage to ...     2         2     10E
# 13  Prevent the next 1 damage that would be dealt ...                     10E
# 14  Double target player's life total. Shuffle Bea...                     10E
# 15  Flash (You may cast this spell any time you co...     2         2     10E
# 16  Flash (You may cast this spell any time you co...     2         2     10E
# 17  Prevent all damage that would be dealt to Cho-...     2         2     10E
# 18  Put target attacking creature on the bottom of...                     10E
# 19                        Destroy target enchantment.                     10E
# 20  Other Soldier creatures get +1/+1 and have fir...     2         2     10E
# 21  Other Soldier creatures get +1/+1 and have fir...     2         2     10E
# 22  {T}: Target creature gets +1/+1 until end of t...     1         1     10E
# 23                   Creatures you control get +1/+1.                     10E
# 24  Hail of Arrows deals X damage divided as you c...                     10E
# 25  Enchant creature (Target a creature as you cas...                     10E
# 26  Enchant creature (Target a creature as you cas...                     10E
# 27  Each creature you control can block an additio...                     10E
# 28  Prevent all combat damage that would be dealt ...                     10E
# 29   Enchant creature\nEnchanted creature gets +1/+2.                     10E
# 30   Enchant creature\nEnchanted creature gets +1/+2.                     10E
# 31     {W}: Honor Guard gets +0/+1 until end of turn.     1         1     10E
# 32  {1}{W}{W}: Target creature gets +1/+1 until en...     1         1     10E
# 33  {T}: All combat damage that would be dealt to ...     2         5     10E
# 34                     {W}, {T}: Tap target creature.     3         3     10E
# 35  When Loyal Sentry blocks a creature, destroy t...     1         1     10E
# 36  Prevent all damage that black sources and red ...                     10E
# 37  Soldier creatures have vigilance.\n{2}{W}: Cre...                     10E
# 38  Soldier creatures have vigilance.\n{2}{W}: Cre...                     10E
# 39  {W}, {T}: Put target Aura card from a graveyar...     2         2     10E
# 40  {W}, {T}: Put target Aura card from a graveyar...     2         2     10E
# 41  Enchant creature\nEnchanted creature can't att...                     10E
# 42  Enchant creature\nEnchanted creature can't att...                     10E
# 43  First strike, protection from black and from r...     2         2     10E
# 44  First strike, protection from black and from r...     2         2     10E
# 45  Enchant creature\nAll damage that would be dea...                     10E
# 46  Enchant creature\nAll damage that would be dea...                     10E
# 47                     You gain 3 life.\nDraw a card.                     10E
# 48  Flying\nAt the beginning of your upkeep, you m...     4         6     10E
# 49  Flying\nAt the beginning of your upkeep, you m...     4         6     10E
#
#       rarity                                         legalities isReprint  \
# 0   uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 1   uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 2   uncommon  {'commander': 'Legal', 'duel': 'Legal', 'gladi...      True
# 3   uncommon  {'commander': 'Legal', 'duel': 'Legal', 'gladi...      True
# 4     common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 5     common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 6       rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 7     common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 8     common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 9   uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 10    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 11    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 12  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 13    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 14      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 15    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 16    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 17      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 18  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 19    common  {'commander': 'Legal', 'duel': 'Legal', 'explo...      True
# 20      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 21      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 22    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 23      rare  {'commander': 'Legal', 'duel': 'Legal', 'explo...      True
# 24  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 25    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 26    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 27  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 28    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 29    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 30    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 31    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 32  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 33      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 34    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 35      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 36  uncommon  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 37      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 38      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 39      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 40      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 41    common  {'commander': 'Legal', 'duel': 'Legal', 'explo...      True
# 42    common  {'commander': 'Legal', 'duel': 'Legal', 'explo...      True
# 43      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 44      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 45      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 46      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 47    common  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 48      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
# 49      rare  {'commander': 'Legal', 'duel': 'Legal', 'legac...      True
#
#                       prices
# 0         [0, 0.26, 0, 0.58]
# 1      [0.08, 0, 0.02, 0.01]
# 2    [1.58, 0.1, 4.45, 0.01]
# 3        [0.6, 0, 0.5, 0.01]
# 4      [0.12, 0.05, 0.35, 0]
# 5      [0.08, 0, 0.01, 0.01]
# 6    [4.0, 2.05, 5.94, 1.23]
# 7      [0.05, 0.05, 0.01, 0]
# 8       [1.6, 0, 0.24, 0.01]
# 9    [20.0, 2.3, 30.9, 2.92]
# 10       [4.0, 0.3, 0, 0.02]
# 11     [0.06, 0, 0.01, 0.01]
# 12  [0.06, 0.05, 0.01, 0.01]
# 13   [8.5, 0.05, 7.87, 0.01]
# 14    [8.5, 1.0, 6.81, 1.93]
# 15        [0.05, 0.05, 0, 0]
# 16     [0.16, 0, 0.27, 0.01]
# 17    [9.0, 0.1, 5.53, 0.08]
# 18   [0.75, 0.05, 1.1, 0.01]
# 19  [0.06, 0.05, 0.01, 0.01]
# 20           [0, 0.05, 0, 0]
# 21       [3.6, 0, 6.7, 2.43]
# 22  [0.05, 0.05, 0.01, 0.01]
# 23   [1.6, 0.26, 3.18, 0.24]
# 24  [0.06, 0.05, 0.12, 0.01]
# 25        [0, 0.05, 0, 0.01]
# 26     [0.06, 0, 0.01, 0.01]
# 27   [0.1, 0.05, 0.01, 0.01]
# 28   [0.7, 0.05, 1.56, 0.01]
# 29      [0, 620.0, 0, 756.0]
# 30      [0.5, 0, 0.02, 0.01]
# 31  [0.05, 0.05, 0.01, 0.01]
# 32  [0.06, 0.05, 0.01, 0.01]
# 33    [0.45, 0.1, 0.3, 0.07]
# 34  [0.06, 0.05, 0.01, 0.01]
# 35    [1.4, 0.1, 0.29, 0.06]
# 36  [0.06, 0.05, 0.01, 0.01]
# 37              [0, 0, 0, 0]
# 38      [2.03, 0, 1.57, 0.3]
# 39    [7.8, 4.2, 7.76, 3.92]
# 40      [8.0, 0, 7.43, 3.59]
# 41        [0, 0.11, 0, 0.22]
# 42     [0.08, 0, 0.14, 0.01]
# 43       [18.0, 0, 21.72, 0]
# 44     [0.88, 0, 1.87, 0.24]
# 45    [7.0, 4.4, 6.05, 3.88]
# 46      [8.0, 0, 8.84, 2.57]
# 47  [0.06, 0.05, 0.01, 0.01]
# 48        [0, 0.05, 0, 0.02]
# 49      [7.8, 0, 2.31, 1.43]

# %%
print(x[9])
# Out:
# 1 W W Enchantment Artifact and enchantment spells your opponents cast cost {2} more to cast.
# Sacrifice Aura of Silence: Destroy target artifact or enchantment.   10E uncommon {'commander': 'Legal', 'duel': 'Legal', 'legacy': 'Legal', 'modern': 'Legal', 'premodern': 'Legal', 'vintage': 'Legal'} True
